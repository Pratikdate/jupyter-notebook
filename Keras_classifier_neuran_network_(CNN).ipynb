# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratikdate/jupyter-notebook/blob/main/Keras_classifier_neuran_network_(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D

from keras.layers import Flatten,Dense

# example of loading an image with the Keras API
from keras.preprocessing.image import load_img

# %%
#initialing the cnn
Classifier =Sequential()
#convulation
Classifier.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
#pooling

Classifier.add(MaxPooling2D(pool_size=(2,2)))

#adding second covulation layer
Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
#flatting
Classifier.add(Flatten())
#Full conectio
Classifier.add(Dense(units=128,activation='relu'))

Classifier.add(Dense(units=1,activation='sigmoid'))
#compal8ng the cnn,
Classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#siting images in cnn
from keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(rescale=1./255)
training_set= train_datagen.flow_from_directory('Images ',target_size=(64,64),batch_size=32,class_mode='binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-bbea5a9ec17c> in <module>()
#       3
#       4 train_datagen=ImageDataGenerator(rescale=1./255)
# ----> 5 training_set= train_datagen.flow_from_directory('Images ',target_size=(64,64),batch_size=32,class_mode='binary')
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#     990         follow_links=follow_links,
#     991         subset=subset,
# --> 992         interpolation=interpolation)
#     993
#     994   def flow_from_dataframe(self,
#
# ...

# %%
from PIL import Image
from urllib import request
from io import BytesIO
from matplotlib import pyplot as plt 

url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8NXdapPuifkKjAW_7zf5DYnspOQFREZyiDQ&s"
res = request.urlopen(url).read()
Sample_Image = Image.open(BytesIO(res)).resize((150,150))

plt.imshow(Sample_Image)

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import save_img
from keras.preprocessing.image import img_to_array
# load image as as grayscale
url='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8NXdapPuifkKjAW_7zf5DYnspOQFREZyiDQ&s'
img = load_img(Sample_Image, grayscale=True)
# convert image to a numpy array
img_array = img_to_array(img)
# save the image with a new filename
save_img('bondi_beach_grayscale.jpg', img_array)
# load the image to confirm it was saved correctly
img = load_img('bondi_beach_grayscale.jpg')
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
img.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-b821ee03cf4a> in <module>()
#       5 # load image as as grayscale
#       6 url='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8NXdapPuifkKjAW_7zf5DYnspOQFREZyiDQ&s'
# ----> 7 img = load_img(Sample_Image, grayscale=True)
#       8 # convert image to a numpy array
#       9 img_array = img_to_array(img)
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# ...
