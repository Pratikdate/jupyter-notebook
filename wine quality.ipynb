# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model,metrics

data=pd.read_csv("winequality-red.csv")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
x=data.drop(columns=["quality"])
y=data.quality

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model =linear_model.LinearRegression()
model.fit(x_train,y_train)
predict=model.predict(x_test)
predict
#prediction=model.predict([[28,627,4,78,78,33,3,46,45,72,72]])
# Out:
# array([5.01978948, 5.35232048, 5.87460703, 5.54324777, 5.38069189,
#        6.46941518, 4.82656898, 4.9130387 , 5.62484215, 6.10478003,
#        5.99445755, 6.37525126, 5.80930745, 5.81131448, 5.00793239,
#        5.52307846, 5.84790553, 5.83432354, 6.02042224, 5.36537372,
#        5.81126107, 5.82130349, 4.93527814, 6.15734768, 5.10531759,
#        6.58507   , 6.08264657, 5.844248  , 5.48789452, 4.76223563,
#        5.39715617, 5.14749759, 6.49433468, 4.90697656, 5.95300267,
#        4.98811155, 5.30105305, 5.63468977, 6.11337336, 5.74632894,
#        5.51530101, 5.66998637, 5.79691116, 4.83085442, 4.7127844 ,
#        5.13079272, 5.50347109, 6.31441967, 5.1504656 , 6.05449078,
#        5.64659159, 5.69723232, 5.74650029, 5.87379457, 5.42716035,
#        5.57241571, 6.0097661 , 6.66930322, 5.99410801, 5.68346506,
#        5.1573175 , 5.97536334, 5.69723232, 5.05403365, 5.55179635,
#        5.9520532 , 5.17337999, 6.04518797, 5.01369187, 6.4704824 ,
#        6.09202104, 6.30239229, 5.44396636, 4.41566459, 6.31984553,
#        5.14488609, 6.13248531, 6.05506202, 5.85437742, 4.834662  ,
#        5.6233279 , 6.23905948, 5.13839383, 5.5383317 , 5.59182795,
#        5.76226591, 5.85893826, 5.65530763, 6.0143819 , 5.87832585,
#        5.44974529, 6.20352259, 6.760313  , 5.91001113, 6.7125943 ,
#        5.24919134, 5.1670117 , 5.5707357 , 4.67776976, 4.66689843,
#        5.844248  , 5.59083393, 6.06940244, 6.11769044, 5.12081757,
#        5.54053248, 5.08809654, 6.50006347, 5.51475348, 5.99149326,
#        6.77533641, 5.73273975, 5.0043908 , 5.40305082, 4.89444436,
#        5.06701659, 5.14896131, 5.76570174, 4.97951119, 6.46086369,
#        5.56117398, 6.56073785, 6.36094444, 4.83262158, 5.99242128,
#        5.28367357, 5.6446207 , 5.64742666, 5.0123774 , 5.97536334,
#        5.81218485, 4.79268468, 6.16054419, 6.1666952 , 5.15234588,
#        5.4426802 , 4.51398324, 5.19017502, 5.00466232, 5.22943548,
#        6.06940244, 6.04227498, 5.59522759, 5.2095211 , 5.20484973,
#        5.73309424, 5.54182257, 5.96860352, 5.02284758, 6.19781639,
#        6.33042255, 5.92193224, 5.2205224 , 6.7125943 , 6.14956051,
#        5.91116542, 5.05312203, 6.17625448, 5.65689769, 5.15010466,
#        5.39838489, 6.44223836, 5.12739581, 7.55150282, 6.56322358,
#        5.77298369, 5.23653262, 5.58940645, 5.31722372, 6.06290658,
#        6.60999046, 6.20021424, 5.74404258, 5.00075981, 5.45925652,
#        5.47566626, 5.23387447, 4.72098336, 6.19595175, 5.35270012,
#        5.31865415, 5.03680827, 5.08473638, 6.65332161, 6.01342253,
#        5.48101349, 5.39705279, 6.1795622 , 5.27327934, 5.04387657,
#        5.02005956, 6.23157092, 5.90938014, 5.4957767 , 5.4806862 ,
#        5.88919234, 5.80209742, 5.59812333, 5.25435702, 5.42700836,
#        6.10384192, 5.44092386, 5.78434387, 6.1892446 , 5.26135023,
#        5.4720796 , 5.3682606 , 5.10772678, 4.74794566, 5.8705127 ,
#        6.51576005, 4.99002098, 5.15900957, 5.24401398, 5.26815918,
#        6.45323183, 5.42906299, 5.35674315, 5.32816124, 4.97351311,
#        5.17295037, 5.72004027, 5.32927407, 5.04244523, 5.31601752,
#        6.19114949, 6.13491883, 5.00703231, 6.33421513, 5.30438654,
#        6.18531324, 5.67184557, 5.09822529, 5.37332727, 5.86419552,
#        5.39286257, 5.65689769, 4.97811783, 5.69773448, 5.7600727 ,
#        5.66917218, 5.04749354, 5.87573085, 6.70127849, 5.69479097,
#        5.39972361, 6.18867408, 5.27476134, 6.02042224, 5.12103696,
#        5.36958505, 5.52604475, 6.02279434, 6.01145163, 6.18346495,
#        6.72022241, 5.81277175, 5.04472692, 5.04839502, 5.47488417,
#        5.10863069, 5.4262643 , 6.1874918 , 5.8825076 , 5.12298975,
#        5.27799601, 5.09127531, 6.28121775, 5.23373986, 5.7846633 ,
#        5.27832629, 5.0239796 , 5.37306383, 6.15409828, 6.06806549,
#        6.19245981, 5.73826487, 5.83320684, 6.00391804, 5.13496019,
#        5.34474819, 5.90995323, 5.34339373, 5.12404823, 5.21097314,
#        5.07133972, 6.13405829, 5.04147827, 5.42424419, 5.64659159,
#        5.73646896, 5.40073759, 5.02172262, 5.39634533, 5.24605173,
#        5.68455522, 4.89645134, 6.37728476, 5.4087147 , 6.04447137,
#        5.38558273, 5.33130313, 6.06940244, 5.38592836, 5.46613472,
#        5.35841905, 5.78911935, 6.44089834, 5.21595167, 5.19455949,
#        5.34614841, 5.30977781, 5.23223522, 6.15019813, 5.3218252 ,
#        5.52803134, 5.48713765, 5.74720526, 5.20796853, 6.15041997])

# %%
# %matplotlib inline
plt.scatter(x_train[["pH"]],y_train)
plt.show()

# %%
m=metrics.mean_squared_error(y_test ,predict)
m
# Out:
# 0.38514631111454734

# %%
c=model.coef_
c
# Out:
# array([ 2.53309375e-02, -1.09599218e+00, -3.40984681e-01,  1.31521159e-02,
#        -1.74243557e+00,  4.93396578e-03, -3.12731496e-03, -3.84787323e+00,
#        -5.85025611e-01,  8.20508460e-01,  2.97260624e-01])

# %%
i=model.intercept_
i
# Out:
# 8.410667448965755

# %%
fig = plt.figure(figsize=(4,4))
ax = fig.add_subplot(111, projection='3d') 

ax.scatter(2,3,4)
plt.show()

# %%
fig = plt.figure(figsize=(8,8))

ax = fig.add_subplot(111, projection='3d')

ax.scatter(c,i,m) # plot the point (2,3,4) on the figure

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /data/user/0/ru.iiec.pydroid3/cache/ipykernel_2460/4085994571.py in <module>
# ----> 1 fig = plt.figure(figsize=(8,8))
#       2
#       3 ax = fig.add_subplot(111, projection='3d')
#       4
#       5 ax.scatter(c,i,m) # plot the point (2,3,4) on the figure
#
# NameError: name 'plt' is not defined
